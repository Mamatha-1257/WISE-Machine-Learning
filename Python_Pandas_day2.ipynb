# %% [markdown]
# Making data frames two methods

# %%
import pandas as pd

# %%
example_dict = {'name': ['person1', 'person2', 'person3'], 'age':[23, 24,21]}

# %%
data = pd.DataFrame(example_dict)

# %%
data
# Out:
#       name  age
# 0  person1   23
# 1  person2   24
# 2  person3   21

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
# '~'/                                              m.c
#  14_07_20.pdf                                     me.jpeg
#  18WH1A1257_Mamatha_Narsapuram_Resume.pdf         me.png
#  18WH1A1257_Mamatha_Narsapuram_Resumerecent.pdf   mergeSort.c
#  adharback.png                                    Minecraft/
#  adharfront.jpeg                                  minecraft-sound/
#  Amercian.csv                                     modal1/
#  American.csv                                     modal1.zip
#  anaconda3/                                       Music/
#  Answer.class                                     my-app/
#  Answer.java                                      myapp/
#  a.out*                                           nextPalindrome.c
#  args/                                            nextPalindrome.py
#  BasicCommands/                                   password.py
#  bookmyshow/                                      pdf/
# ...

# %%
file_path = '/home/mamatha/DataMissing.csv'
df = pd.read_csv(file_path)
df
# Out:
#           Country             City           State  Postal Code   Region  \
# 0   United States        Henderson        Kentucky      42420.0    South
# 1   United States        Henderson        Kentucky      42420.0    South
# 2   United States      Los Angeles      California      90036.0     West
# 3   United States  Fort Lauderdale         Florida      33311.0    South
# 4             NaN  Fort Lauderdale         Florida          NaN    South
# 5   United States      Los Angeles      California      90032.0     West
# 6   United States      Los Angeles      California      90032.0     West
# 7   United States      Los Angeles      California      90032.0     West
# 8   United States      Los Angeles      California      90032.0     West
# 9   United States      Los Angeles      California      90032.0      NaN
# 10  United States      Los Angeles      California      90032.0     West
# 11  United States      Los Angeles      California      90032.0     West
# ...

# %% [markdown]
# view the data first 5 rows or last 5 rows

# %%
df.head()
# Out:
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky      42420.0  South
# 1  United States        Henderson    Kentucky      42420.0  South
# 2  United States      Los Angeles  California      90036.0   West
# 3  United States  Fort Lauderdale     Florida      33311.0  South
# 4            NaN  Fort Lauderdale     Florida          NaN  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4              NaN              NaN      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %%
df.tail()
# Out:
#           Country          City         State  Postal Code   Region  \
# 30  United States  Philadelphia  Pennsylvania      19140.0     East
# 31  United States  Philadelphia  Pennsylvania      19140.0     East
# 32  United States  Philadelphia  Pennsylvania      19140.0     East
# 33  United States  Philadelphia  Pennsylvania      19140.0     East
# 34  United States       Houston         Texas      77095.0  Central
#
#          Product ID         Category Sub-Category  \
# 30  OFF-EN-10001509  Office Supplies    Envelopes
# 31  OFF-AR-10004042  Office Supplies          Art
# 32  OFF-BI-10001525  Office Supplies      Binders
# 33  OFF-AR-10001683  Office Supplies          Art
# 34  OFF-PA-10000249  Office Supplies        Paper
#
#                                          Product Name   Sales  Quantity  \
# 30                          Poly String Tie Envelopes   3.264         2
# 31  BOSTON Model 1800 Electric Pencil Sharpeners, ...  86.304         6
# ...

# %% [markdown]
# shape row and cloumn in form of tuple

# %%
df.shape
# Out:
# (35, 13)
